# %% [markdown]
# <a href="https://colab.research.google.com/github/pejmanrasti/EPU_ML_Angers_2023/blob/main/Jour_2/EPU_1_ImportDonneesBrutes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Quelles sont les étapes à suivre dans un projet de machine learning ?
# 1. **Quel est le projet ?**
#   * Objectif ?
#   * Comment le modèle sera-il utilisé en routine clinique ? (opérateur, contexte, contraintes, etc)
#   * Le problème peut-il être résolu plus simplement ? (état des lieux des solutions actuelles)
#   * Comment formuler le problème ? (apprentissage supervisé ou non, classification ou régression, type de données d'entrée, ...)
#   * Comment mesurer la performance et quelle est la performance minimale recherchée ?
#
# 2. **Récupérer les données**
#   * Evaluer quels types de données vont être nécessaires et en quelle quantité
#   * Attention à la RGPD !
#   * Convertir les données dans un format facilement manipulable
#   * Automatiser la collecte autant que possible
#
#   *A noter : en apprentissage supervisé, les données sont constituées de variables et de cibles. Les variables sont utilisées pour prédire les cibles.*
#
# 3. **Analyser les données**
#   * Types de données présentes dans la base (quantitatives, qualitatives, entières ou réelles, etc)
#   * Données manquantes
#   * Données corrompues (données aberrantes, erreurs, etc) : nécessité d'avoir un oeil d'expert sur les données explorées
#   * Visualiser les données pour évaluer les types de distributions (normale, beta, uniforme, etc)
#   * Evaluer les corrélations entre les variables
#   * Vérifier si le problème peut être résolu manuellement (ex : on découvre une forte corrélation entre une variable et les cibles)
#
# 4. **Préparer les données**
#   * Nettoyer les données : supprimer les données aberrantes et remplacer ou supprimer les observations (lignes de la base) présentant des données manquantes.
#   * Supprimer les données non pertinentes
#   * Transformer les données : transformer des variables discrètes en variables continues ou inversement au besoin, appliquer des transformations potentiellement intéressantes (log, racine, carré, etc), combiner des variables entre-elles
#   * Calibrer les variables
#   * Séparer les données : conserver des données test qui ne seront jamais utilisées pour entrainer le modèle.
#
# 5. **Evaluer plusieurs modèles**
#   * Sélectionner une liste d'algorithmes de différentes familles (linéaire, forêt aléatoire, SVM, réseau de neuronnes, etc)
#   * Sélectionner les variables les plus pertinentes pour chaque algorithme
#   * Dans un 1er temps, on peut entrainer les modèles en utilisant leur hyper-paramètres par défaut ou faire une recherche sur grille rapide.
#   * Pour chaque modèle, comparer les performances obtenues sur les données d'entrainement via une validation croisée à k passes.
#   * Sélectionner quelques uns des modèles testés les plus prometteurs
#
# 6. **Réglage fin des modèles**
#   * Sélectionner les hyper-paramètres via une validation croisée sur les données d'entrainement. Commencer par évaluer les modèles sur une recherche grossière et affiner l'espace de recherche en fonction des résultats.
#   * Eventuellement tester des méthodes ensemblistes qui permettent de combiner plusieurs modèles.
#   * Evaluer les performances du modèle final sur les données test. Attention à ne pas utiliser les données test pendant le réglage du modèle ou à modifier le réglage du modèle en fonction des résultats obtenus sur les données test sinon la mesure de l'erreur de généralisation sur les données test sera biaisée de manière optimiste (sur-ajustement sur les données test).
#
# 7. **Surveiller son modèle**
#   * Si on lance le modèle en routine clinique, il faut prendre garde à ce que les résultats ne dérivent pas. Cela peut arriver si les données d'entrée changent (nouveau détecteur, MAJ de l'algorithme de calcul, modification du type d'analyse réalisé, etc)
#   * Si les données ont changé, il faut réentrainer le modèle

# %% [markdown]
# ---
#
#
#
# ---

# %% [markdown]
# 1. **Quel est le projet ?**

# %% [markdown]
# # Problématique
# * **Prédire les CQ patients hors tolérances pour les plans VMAT des localisations pelviennes afin de réoptimiser ces plans directement**
# * Données disponibles pour chaque plan actuellement dans la base de données patient : prescriptions, codes CIM, machine, énergie, positions du MLC, du bras et débit de dose pour tous les points de contrôles, distributions de dose, résultats du CQ pré-traitement, ...

# %% [markdown]
# ---
#
#
#
# ---

# %% [markdown]
# 2. **Récupérer les données**

# %%
from pandas import read_csv
import re
import numpy

# %% [markdown]
# # Import de la base csv brute issue de l'extraction de données Aria
# * Les données ont été collectées automatiquement via un executable C# et stockées dans un fichier csv

# %%
# On importe le csv qui contient les données brutes via la fonction read_csv de la bibliothèque pandas
df = read_csv("/content/RAWDATABASE.csv",
              sep = ",",
              header=0
              )
df.head()
# Out:
#    Unnamed: 0  Patient_ID      Course_Name Treatment_Plan_Name  \
# 0           0        1007          cq/PDIP                  NR
# 1           1        1007          cq/PDIP                  NR
# 2           2         953  202107 MACHOIRE         RA30_mandDT
# 3           3         953  202107 MACHOIRE         RA30_mandDT
# 4           4         126   202211 COTES G        RA20 cotes G
#
#      Last_modification               CIM  \
# 0     03/07/2023 17:43                NR
# 1     03/07/2023 17:43                NR
# 2     07/12/2021 16:06  C15.9
# 3     07/12/2021 16:06  C15.9
# 4  11/21/2022 15:24:11  C79.5
#
#                                      CIM_description        Presc_name  \
# 0                                                 NR                NR
# 1                                                 NR                NR
# 2  Oesophage, sans precision                     ...        MACHOIRE D
# 3  Oesophage, sans precision                     ...        MACHOIRE D
# 4  Tumeur maligne secondaire des os et de la moel...  6e et 7e COTES G
#
#   Presc_cibles Presc_DoseParFract  ...  Gamma21glob10_MaxGamma  Gamma22glob10  \
# 0           NR                 NR  ...                   1.589          0.999
# 1           NR                 NR  ...                   1.965          0.999
# 2    Isocentre                  3  ...                     NaN            NaN
# 3    Isocentre                  3  ...                     NaN            NaN
# 4    Isocentre                  4  ...                   1.860          0.999
#
#    Gamma22glob10_AverageGamma  Gamma22glob10_MaxGamma Gamma33glob10  \
# 0                       0.157                   1.422           1.0
# 1                       0.147                   1.587           1.0
# 2                         NaN                     NaN           NaN
# 3                         NaN                     NaN           NaN
# 4                       0.149                   1.410           1.0
#
#     Gamma33glob10_AverageGamma  Gamma33glob10_MaxGamma Gamma32glob10  \
# 0                        0.105                   0.948           1.0
# 1                        0.098                   1.058           1.0
# 2                          NaN                     NaN           NaN
# 3                          NaN                     NaN           NaN
# 4                        0.099                   0.940           1.0
#
#    Gamma32glob_AverageGamma  Gamma32glob10_MaxGamma
# 0                     0.127                   1.006
# 1                     0.121                   1.209
# 2                       NaN                     NaN
# 3                       NaN                     NaN
# 4                     0.128                   1.137
#
# [5 rows x 288 columns]

# %%
# La méthode info() permet d'avoir un résumé de la base de données : nbre de colonnes et de lignes, types de données présentes
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2417 entries, 0 to 2416
# Columns: 288 entries, Unnamed: 0 to  Gamma32glob10_MaxGamma
# dtypes: float64(107), int64(10), object(171)
# memory usage: 5.3+ MB

# %%
# On jette un oeil sur les données qui sont des float
 [c for c in df.columns if df[c].dtype == "float64"]
# Out:
# ['Plan_DoseParFraction',
#  'Plan_CalcGrid',
#  'MUperGy',
#  'MUmax',
#  'MUstd',
#  'MUiqr',
#  'AAV',
#  'AAVmin',
#  'AAVmax',
#  'AAVstd',
#  'AAViqr',
#  'LSV',
#  'LSVmin',
#  'LSVmax',
#  'LSVstd',
#  'LSViqr',
#  'MCS',
#  'MCSmin',
#  'MCSmax',
#  'MCSstd',
#  'MCSiqr',
#  'AFW',
#  'AFWmin',
#  'AFWmax',
#  'AFWstd',
#  'AFWiqr',
#  'ALT',
#  'CAS',
#  'CASmax',
#  'CASstd',
#  'CASiqr',
#  'CLS',
#  'CLSmin',
#  'CLSmax',
#  'CLSstd',
#  'CLSiqr',
#  'MAD',
#  'MADmax',
#  'MADstd',
#  'MADiqr',
#  'MFA',
#  'MFAmax',
#  'MFAstd',
#  'MFAiqr',
#  'SAS2',
#  'SAS2max',
#  'SAS2std',
#  'SAS2iqr',
#  'SAS5',
#  'SAS5max',
#  'SAS5std',
#  'SAS5iqr',
#  'SAS10',
#  'SAS10max',
#  'SAS10std',
#  'SAS10iqr',
#  'SAS20',
#  'SAS20max',
#  'SAS20std',
#  'SAS20iqr',
#  'EM',
#  'EMmin',
#  'EMmax',
#  'EMstd',
#  'EMiqr',
#  'MIt02',
#  'BI',
#  'BImin',
#  'BImax',
#  'BIstd',
#  'BIiqr',
#  'BM',
#  'BA',
#  'BAmin',
#  'BAmax',
#  'BAstd',
#  'BAiqr',
#  'Gamma11loc10',
#  ' Gamma11loc10_AverageGamma',
#  ' Gamma11loc10_MaxGamma',
#  'Gamma21loc10',
#  ' Gamma21loc10_AverageGamma',
#  ' Gamma21loc10_MaxGamma',
#  'Gamma22loc10',
#  ' Gamma22loc10_AverageGamma',
#  ' Gamma22loc10_MaxGamma',
#  'Gamma33loc10',
#  ' Gamma33loc10_AverageGamma',
#  ' Gamma33loc10_MaxGamma',
#  'Gamma32loc10',
#  ' Gamma32loc10_AverageGamma',
#  ' Gamma32loc10_MaxGamma',
#  'Gamma11glob10',
#  ' Gamma11glob10_AverageGamma',
#  ' Gamma11glob10_MaxGamma',
#  'Gamma21glob10',
#  ' Gamma21glob10_AverageGamma',
#  ' Gamma21glob10_MaxGamma',
#  'Gamma22glob10',
#  ' Gamma22glob10_AverageGamma',
#  ' Gamma22glob10_MaxGamma',
#  'Gamma33glob10',
#  ' Gamma33glob10_AverageGamma',
#  ' Gamma33glob10_MaxGamma',
#  'Gamma32glob10',
#  ' Gamma32glob_AverageGamma',
#  ' Gamma32glob10_MaxGamma']

# %%
# On jette un oeil pour voir quelles données sont des int
[c for c in df.columns if df[c].dtype == "int64"]
# Out:
# ['Unnamed: 0',
#  'Patient_ID',
#  'MUmin',
#  'CASmin',
#  'MADmin',
#  'MFAmin',
#  'SAS2min',
#  'SAS5min',
#  'SAS10min',
#  'SAS20min']

# %%
# On jette un oeil pour voir quelles données sont classées comme "object" = non défini lors de l'import.
# En général les données qui comportent du texte sont importées comme des objets. Si on veut les utiliser, il faut dire à pandas que ce sont des string par exemple
# Ici toutes les PCM avec _prox ou _dist sont spécifiques à l'Halcyon. Pour le Novalis ces données sont étiquetées comme "NR" (paramétré lors de la collecte)
# Il est important de savoir comment les données ont été collectées pour anticiper des problèmes
[c for c in df.columns if df[c].dtype == "object"]
# Out:
# ['Course_Name',
#  'Treatment_Plan_Name',
#  'Last_modification',
#  'CIM',
#  'CIM_description',
#  'Presc_name',
#  'Presc_cibles',
#  'Presc_DoseParFract',
#  'Presc_Fractions',
#  'Plan_NbreFractions',
#  'Plan_GroupeStruct',
#  'Plan_ModeleCalc',
#  'PDIP_Plan_Name',
#  'PDIP_UID',
#  'Technique',
#  'Machine',
#  'Beam',
#  'AAV_prox',
#  'AAVmin_prox',
#  'AAVmax_prox',
#  'AAVstd_prox',
#  'AAViqr_prox',
#  'AAV_dist',
#  'AAVmin_dist',
#  'AAVmax_dist',
#  'AAVstd_dist',
#  'AAViqr_dist',
#  'LSV_prox',
#  'LSVmin_prox',
#  'LSVmax_prox',
#  'LSVstd_prox',
#  'LSViqr_prox',
#  'LSV_dist',
#  'LSVmin_dist',
#  'LSVmax_dist',
#  'LSVstd_dist',
#  'LSViqr_dist',
#  'MCS_prox',
#  'MCSmin_prox',
#  'MCSmax_prox',
#  'MCSstd_prox',
#  'MCSiqr_prox',
#  'MCS_dist',
#  'MCSmin_dist',
#  'MCSmax_dist',
#  'MCSstd_dist',
#  'MCSiqr_dist',
#  'AFW_prox',
#  'AFWmin_prox',
#  'AFWmax_prox',
#  'AFWstd_prox',
#  'AFWiqr_prox',
#  'AFW_dist',
#  'AFWmin_dist',
#  'AFWmax_dist',
#  'AFWstd_dist',
#  'AFWiqr_dist',
#  'ALT_prox',
#  'ALT_dist',
#  'CAS_prox',
#  'CASmin_prox',
#  'CASmax_prox',
#  'CASstd_prox',
#  'CASiqr_prox',
#  'CAS_dist',
#  'CASmin_dist',
#  'CASmax_dist',
#  'CASstd_dist',
#  'CASiqr_dist',
#  'CLS_prox',
#  'CLSmin_prox',
#  'CLSmax_prox',
#  'CLSstd_prox',
#  'CLSiqr_prox',
#  'CLS_dist',
#  'CLSmin_dist',
#  'CLSmax_dist',
#  'CLSstd_dist',
#  'CLSiqr_dist',
#  'MAD_prox',
#  'MADmin_prox',
#  'MADmax_prox',
#  'MADstd_prox',
#  'MADiqr_prox',
#  'MAD_dist',
#  'MADmin_dist',
#  'MADmax_dist',
#  'MADstd_dist',
#  'MADiqr_dist',
#  'MFA_prox',
#  'MFAmin_prox',
#  'MFAmax_prox',
#  'MFAstd_prox',
#  'MFAiqr_prox',
#  'MFA_dist',
#  'MFAmin_dist',
#  'MFAmax_dist',
#  'MFAstd_dist',
#  'MFAiqr_dist',
#  'SAS2_prox',
#  'SAS2min_prox',
#  'SAS2max_prox',
#  'SAS2std_prox',
#  'SAS2iqr_prox',
#  'SAS2_dist',
#  'SAS2min_dist',
#  'SAS2max_dist',
#  'SAS2std_dist',
#  'SAS2iqr_dist',
#  'SAS5_prox',
#  'SAS5min_prox',
#  'SAS5max_prox',
#  'SAS5std_prox',
#  'SAS5iqr_prox',
#  'SAS5_dist',
#  'SAS5min_dist',
#  'SAS5max_dist',
#  'SAS5std_dist',
#  'SAS5iqr_dist',
#  'SAS10_prox',
#  'SAS10min_prox',
#  'SAS10max_prox',
#  'SAS10std_prox',
#  'SAS10iqr_prox',
#  'SAS10_dist',
#  'SAS10min_dist',
#  'SAS10max_dist',
#  'SAS10std_dist',
#  'SAS10iqr_dist',
#  'SAS20_prox',
#  'SAS20min_prox',
#  'SAS20max_prox',
#  'SAS20std_prox',
#  'SAS20iqr_prox',
#  'SAS20_dist',
#  'SAS20min_dist',
#  'SAS20max_dist',
#  'SAS20std_dist',
#  'SAS20iqr_dist',
#  'EM_prox',
#  'EMmin_prox',
#  'EMmax_prox',
#  'EMstd_prox',
#  'EMiqr_prox',
#  'EM_dist',
#  'EMmin_dist',
#  'EMmax_dist',
#  'EMstd_dist',
#  'EMiqr_dist',
#  'BI_prox',
#  'BImin_prox',
#  'BImax_prox',
#  'BIstd_prox',
#  'BIiqr_prox',
#  'BI_dist',
#  'BImin_dist',
#  'BImax_dist',
#  'BIstd_dist',
#  'BIiqr_dist',
#  'BM_prox',
#  'BM_dist',
#  'BA_prox',
#  'BAmin_prox',
#  'BAmax_prox',
#  'BAstd_prox',
#  'BAiqr_prox',
#  'BA_dist',
#  'BAmin_dist',
#  'BAmax_dist',
#  'BAstd_dist',
#  'BAiqr_dist']

# %%
# La méthode describe() permet de faire un résumé de la distribution des données de chaque colonne de la base
df.describe()
# Out:
#         Unnamed: 0   Patient_ID  Plan_DoseParFraction  Plan_CalcGrid  \
# count  2417.000000  2417.000000           2409.000000    2417.000000
# mean   1208.000000   512.257344              2.842134       0.242056
# std     697.872123   296.827961              1.839080       0.033599
# min       0.000000     0.000000              1.800000       0.100000
# 25%     604.000000   257.000000              2.000000       0.250000
# 50%    1208.000000   510.000000              2.100000       0.250000
# 75%    1812.000000   773.000000              3.000000       0.250000
# max    2416.000000  1018.000000             20.000000       0.250000
#
#            MUperGy   MUmin        MUmax        MUstd        MUiqr  \
# count  2417.000000  2417.0  2417.000000  2417.000000  2417.000000
# mean    258.237909     0.0     0.012373     0.001926     0.002118
# std      49.074723     0.0     0.006559     0.001260     0.001660
# min     132.155062     0.0     0.005982     0.000546     0.000009
# 25%     223.681493     0.0     0.007902     0.001030     0.000965
# 50%     256.206928     0.0     0.010126     0.001595     0.001662
# 75%     288.122398     0.0     0.015112     0.002393     0.002722
# max     480.581511     0.0     0.090658     0.012491     0.016940
#
#                AAV  ...   Gamma21glob10_MaxGamma  Gamma22glob10  \
# count  2417.000000  ...              1900.000000    1900.000000
# mean      0.363556  ...                 2.349695       0.995813
# std       0.092088  ...                 1.045727       0.032604
# min       0.059863  ...                 0.590000       0.146000
# 25%       0.302769  ...                 1.601000       0.996000
# 50%       0.356074  ...                 2.161000       0.999000
# 75%       0.415040  ...                 2.838000       1.000000
# max       0.744318  ...                10.000000       1.000000
#
#         Gamma22glob10_AverageGamma   Gamma22glob10_MaxGamma  Gamma33glob10  \
# count                  1900.000000              1900.000000    1900.000000
# mean                      0.166091                 1.902409       0.998428
# std                       0.155571                 0.875619       0.029061
# min                       0.079000                 0.435000       0.219000
# 25%                       0.135750                 1.326500       1.000000
# 50%                       0.157000                 1.726000       1.000000
# 75%                       0.180000                 2.262500       1.000000
# max                       4.607000                10.000000       1.000000
#
#         Gamma33glob10_AverageGamma   Gamma33glob10_MaxGamma  Gamma32glob10  \
# count                  1900.000000              1900.000000    1900.000000
# mean                      0.110798                 1.271814       0.997985
# std                       0.106005                 0.624840       0.031708
# min                       0.053000                 0.290000       0.165000
# 25%                       0.090000                 0.883750       0.999000
# 50%                       0.104500                 1.150500       1.000000
# 75%                       0.120000                 1.508250       1.000000
# max                       3.127000                10.000000       1.000000
#
#         Gamma32glob_AverageGamma   Gamma32glob10_MaxGamma
# count                1900.000000              1900.000000
# mean                    0.142485                 1.446021
# std                     0.138498                 0.692240
# min                     0.069000                 0.361000
# 25%                     0.116000                 0.993750
# 50%                     0.134000                 1.324500
# 75%                     0.154000                 1.738000
# max                     4.085000                10.000000
#
# [8 rows x 117 columns]

# %% [markdown]
# # Sélection des données
# * Toutes les données ne vont pas être utiles
# * Certaines données sont manquantes ou dupliquées

# %% [markdown]
# ## Données VMAT issues du Novalis et calculées en AAA.

# %%
#On garde les données Novalis, en VMAT,l'algo AAA avec grille de calcul 0.25
#Comme on va filtrer en fonction des locs ensuite, on supprime également les lignes où le code CIM est absent
df = df[df.Technique!='DoseDynamic']
df = df[df.Machine=='NOVALIS']
df = df[df.Gamma22loc10!='NR']
df = df[df.Plan_CalcGrid==0.25]
df = df[df.Plan_ModeleCalc!='Acuros_1610']
df = df[df.CIM!='NR']

#On supprime toutes les colonnes qui ne sont pas des float (analyse préalable de la base = toutes les colonnes hors PCM, résultats gamma et ID patients)
for c in df.columns:
    if c !='CIM' : #On garde la colonne des codes CIM
        if df[c].dtype == 'object':
            df = df.drop(columns=[c])

# %%
#Affichage des colonnes restantes dans df
list(df.columns)
# Out:
# ['Unnamed: 0',
#  'Patient_ID',
#  'CIM',
#  'Plan_DoseParFraction',
#  'Plan_CalcGrid',
#  'MUperGy',
#  'MUmin',
#  'MUmax',
#  'MUstd',
#  'MUiqr',
#  'AAV',
#  'AAVmin',
#  'AAVmax',
#  'AAVstd',
#  'AAViqr',
#  'LSV',
#  'LSVmin',
#  'LSVmax',
#  'LSVstd',
#  'LSViqr',
#  'MCS',
#  'MCSmin',
#  'MCSmax',
#  'MCSstd',
#  'MCSiqr',
#  'AFW',
#  'AFWmin',
#  'AFWmax',
#  'AFWstd',
#  'AFWiqr',
#  'ALT',
#  'CAS',
#  'CASmin',
#  'CASmax',
#  'CASstd',
#  'CASiqr',
#  'CLS',
#  'CLSmin',
#  'CLSmax',
#  'CLSstd',
#  'CLSiqr',
#  'MAD',
#  'MADmin',
#  'MADmax',
#  'MADstd',
#  'MADiqr',
#  'MFA',
#  'MFAmin',
#  'MFAmax',
#  'MFAstd',
#  'MFAiqr',
#  'SAS2',
#  'SAS2min',
#  'SAS2max',
#  'SAS2std',
#  'SAS2iqr',
#  'SAS5',
#  'SAS5min',
#  'SAS5max',
#  'SAS5std',
#  'SAS5iqr',
#  'SAS10',
#  'SAS10min',
#  'SAS10max',
#  'SAS10std',
#  'SAS10iqr',
#  'SAS20',
#  'SAS20min',
#  'SAS20max',
#  'SAS20std',
#  'SAS20iqr',
#  'EM',
#  'EMmin',
#  'EMmax',
#  'EMstd',
#  'EMiqr',
#  'MIt02',
#  'BI',
#  'BImin',
#  'BImax',
#  'BIstd',
#  'BIiqr',
#  'BM',
#  'BA',
#  'BAmin',
#  'BAmax',
#  'BAstd',
#  'BAiqr',
#  'Gamma11loc10',
#  ' Gamma11loc10_AverageGamma',
#  ' Gamma11loc10_MaxGamma',
#  'Gamma21loc10',
#  ' Gamma21loc10_AverageGamma',
#  ' Gamma21loc10_MaxGamma',
#  'Gamma22loc10',
#  ' Gamma22loc10_AverageGamma',
#  ' Gamma22loc10_MaxGamma',
#  'Gamma33loc10',
#  ' Gamma33loc10_AverageGamma',
#  ' Gamma33loc10_MaxGamma',
#  'Gamma32loc10',
#  ' Gamma32loc10_AverageGamma',
#  ' Gamma32loc10_MaxGamma',
#  'Gamma11glob10',
#  ' Gamma11glob10_AverageGamma',
#  ' Gamma11glob10_MaxGamma',
#  'Gamma21glob10',
#  ' Gamma21glob10_AverageGamma',
#  ' Gamma21glob10_MaxGamma',
#  'Gamma22glob10',
#  ' Gamma22glob10_AverageGamma',
#  ' Gamma22glob10_MaxGamma',
#  'Gamma33glob10',
#  ' Gamma33glob10_AverageGamma',
#  ' Gamma33glob10_MaxGamma',
#  'Gamma32glob10',
#  ' Gamma32glob_AverageGamma',
#  ' Gamma32glob10_MaxGamma']

# %%
#On garde seulement les PCMs, les CIMs et l'analyse gamma en 2%/2mm local
df = df.drop(columns=[
    'Patient_ID',
'Unnamed: 0',
 'Plan_DoseParFraction',
 'Plan_CalcGrid',
 'Gamma11loc10',
 ' Gamma11loc10_AverageGamma',
 ' Gamma11loc10_MaxGamma',
 'Gamma21loc10',
 ' Gamma21loc10_AverageGamma',
 ' Gamma21loc10_MaxGamma',
 #' Gamma22loc10',
 ' Gamma22loc10_AverageGamma',
 ' Gamma22loc10_MaxGamma',
 'Gamma33loc10',
 ' Gamma33loc10_AverageGamma',
 ' Gamma33loc10_MaxGamma',
 'Gamma32loc10',
 ' Gamma32loc10_AverageGamma',
 ' Gamma32loc10_MaxGamma',
 'Gamma11glob10',
 ' Gamma11glob10_AverageGamma',
 ' Gamma11glob10_MaxGamma',
 'Gamma21glob10',
 ' Gamma21glob10_AverageGamma',
 ' Gamma21glob10_MaxGamma',
 'Gamma22glob10',
 ' Gamma22glob10_AverageGamma',
 ' Gamma22glob10_MaxGamma',
 'Gamma33glob10',
 ' Gamma33glob10_AverageGamma',
 ' Gamma33glob10_MaxGamma',
 'Gamma32glob10',
 ' Gamma32glob_AverageGamma',
 ' Gamma32glob10_MaxGamma'])

df = df.reset_index()
df = df.drop(columns=['index'])

# %%
df.head()
# Out:
#                 CIM     MUperGy  MUmin     MUmax     MUstd     MUiqr  \
# 0  C15.9             188.609536      0  0.015320  0.002248  0.002120
# 1  C15.9             188.609536      0  0.014070  0.001965  0.001997
# 2  C79.5             286.279357      0  0.025226  0.005673  0.007483
# 3  C79.5             286.279357      0  0.031176  0.009321  0.016940
# 4  C79.5             237.155273      0  0.015816  0.003171  0.004838
#
#         AAV    AAVmin    AAVmax    AAVstd  ...      BImax      BIstd  \
# 0  0.344026  0.164413  0.570164  0.111751  ...   5.708773   1.057829
# 1  0.376546  0.209365  0.633108  0.085748  ...   9.279901   1.523452
# 2  0.212154  0.004097  0.470404  0.144776  ...  29.291912   7.922034
# 3  0.199329  0.004267  0.650373  0.205439  ...  27.954796  11.082609
# 4  0.363556  0.055128  0.708376  0.197273  ...   7.922318   1.369862
#
#        BIiqr        BM         BA    BAmin       BAmax      BAstd      BAiqr  \
# 0   1.669608  0.546731  37.466117  17.5350   59.019999  11.509763  20.900000
# 1   1.925466  0.525014  31.496345  19.2200   51.920000   6.456780   9.096875
# 2   5.100115  0.680998  35.918076   0.7750   76.077499  24.333914  46.084374
# 3  25.520850  0.734694  32.592787   0.7750  105.114999  33.919277  58.263750
# 4   1.865898  0.572010  79.412440  12.9025  146.812498  40.413525  66.943749
#
#    Gamma22loc10
# 0           NaN
# 1           NaN
# 2         0.995
# 3         0.990
# 4         0.999
#
# [5 rows x 85 columns]

# %% [markdown]
# ## Localisation pelvienne

# %%
# On ne garde que les lignes de données associées à la loc Pelvis (Prostate, Pelvis gyneco)

#Codes CIM associés à des locs pelviennes
code_pelv = ['C18.7', 'C19', 'C20', 'C21.0', 'C21.1', 'C51.8', 'C51.9', 'C52','C53.0','C53.1','C53.8','C53.9','C54.1',
            'C54.8','C54.9','C56','C61','C62.9','C66', 'C67.8','C67.9','C77.4','C77.5','C77.5','C79.1','C79.3','C79.5',
            'C82.9','D26.1']

#Conversion du code CIM de "Object" à "String"
df["CIM"] = df['CIM'].astype('string')

# %%
# Quand on fait la collecte de données, notamment des données texte, on peut se retrouver avec des étrangetés
# Ici par exemple avec cet affichage on peut voit que des espaces sont présents avant et après les codes CIM (pas tous en réalité)
# Si on fait un filtre des codes CIM via la liste précédemment définie, aucune donnée ne sera retrouvée
print("XXX", df["CIM"][1], "XXX")
# Out:
# XXX C15.9            XXX

# %%
#On supprime les espaces qu'il y a pour certains CIM
for i in range(len(df["CIM"])):
    df["CIM"][i] = re.sub(r"\s+$", "", df["CIM"][i])

#On filtre la base en fonction des codes CIM de la liste code_pelv
df = df[df.CIM.isin(code_pelv)]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1451 entries, 2 to 2253
# Data columns (total 85 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   CIM           1451 non-null   string
#  1   MUperGy       1451 non-null   float64
#  2   MUmin         1451 non-null   int64
#  3   MUmax         1451 non-null   float64
#  4   MUstd         1451 non-null   float64
#  5   MUiqr         1451 non-null   float64
#  6   AAV           1451 non-null   float64
#  7   AAVmin        1451 non-null   float64
#  8   AAVmax        1451 non-null   float64
#  9   AAVstd        1451 non-null   float64
#  10  AAViqr        1451 non-null   float64
#  11  LSV           1451 non-null   float64
#  12  LSVmin        1451 non-null   float64
#  13  LSVmax        1451 non-null   float64
#  14  LSVstd        1451 non-null   float64
#  15  LSViqr        1451 non-null   float64
#  16  MCS           1451 non-null   float64
#  17  MCSmin        1451 non-null   float64
#  18  MCSmax        1451 non-null   float64
#  19  MCSstd        1451 non-null   float64
#  20  MCSiqr        1451 non-null   float64
#  21  AFW           1451 non-null   float64
#  22  AFWmin        1451 non-null   float64
#  23  AFWmax        1451 non-null   float64
#  24  AFWstd        1451 non-null   float64
#  25  AFWiqr        1451 non-null   float64
#  26  ALT           1451 non-null   float64
#  27  CAS           1451 non-null   float64
#  28  CASmin        1451 non-null   int64
#  29  CASmax        1451 non-null   float64
#  30  CASstd        1451 non-null   float64
#  31  CASiqr        1451 non-null   float64
#  32  CLS           1451 non-null   float64
#  33  CLSmin        1451 non-null   float64
#  34  CLSmax        1451 non-null   float64
#  35  CLSstd        1451 non-null   float64
#  36  CLSiqr        1451 non-null   float64
#  37  MAD           1451 non-null   float64
#  38  MADmin        1451 non-null   int64
#  39  MADmax        1451 non-null   float64
#  40  MADstd        1451 non-null   float64
#  41  MADiqr        1451 non-null   float64
#  42  MFA           1451 non-null   float64
#  43  MFAmin        1451 non-null   int64
#  44  MFAmax        1451 non-null   float64
#  45  MFAstd        1451 non-null   float64
#  46  MFAiqr        1451 non-null   float64
#  47  SAS2          1451 non-null   float64
#  48  SAS2min       1451 non-null   int64
#  49  SAS2max       1451 non-null   float64
#  50  SAS2std       1451 non-null   float64
#  51  SAS2iqr       1451 non-null   float64
#  52  SAS5          1451 non-null   float64
#  53  SAS5min       1451 non-null   int64
#  54  SAS5max       1451 non-null   float64
#  55  SAS5std       1451 non-null   float64
#  56  SAS5iqr       1451 non-null   float64
#  57  SAS10         1451 non-null   float64
#  58  SAS10min      1451 non-null   int64
#  59  SAS10max      1451 non-null   float64
#  60  SAS10std      1451 non-null   float64
#  61  SAS10iqr      1451 non-null   float64
#  62  SAS20         1451 non-null   float64
#  63  SAS20min      1451 non-null   int64
#  64  SAS20max      1451 non-null   float64
#  65  SAS20std      1451 non-null   float64
#  66  SAS20iqr      1451 non-null   float64
#  67  EM            1451 non-null   float64
#  68  EMmin         1451 non-null   float64
#  69  EMmax         1451 non-null   float64
#  70  EMstd         1451 non-null   float64
#  71  EMiqr         1451 non-null   float64
#  72  MIt02         1451 non-null   float64
#  73  BI            1451 non-null   float64
#  74  BImin         1451 non-null   float64
#  75  BImax         1451 non-null   float64
#  76  BIstd         1451 non-null   float64
#  77  BIiqr         1451 non-null   float64
#  78  BM            1451 non-null   float64
#  79  BA            1451 non-null   float64
#  80  BAmin         1451 non-null   float64
#  81  BAmax         1451 non-null   float64
#  82  BAstd         1451 non-null   float64
#  83  BAiqr         1451 non-null   float64
#  84  Gamma22loc10  1340 non-null   float64
# dtypes: float64(76), int64(8), string(1)
# memory usage: 974.9 KB

# %%
# Une fois que le filtrage en fonction des codes CIM a été fait, on n'a plus besoin de cette colonne donc on la supprime
df = df.drop(columns = ["CIM"])

# %% [markdown]
# ## Suppression des lignes dupliquées et des lignes avec des valeurs manquantes
# >Selon les cas, il est également possible de combler les éventuelles valeurs manquantes en leur attribuant une valeur (zéro, moyenne, médiane), des fonctions scikit-learn le font automatiquement.

# %%
#Suppression des lignes dupliquées et des lignes avec des valeurs manquantes
df = df.drop_duplicates()
df = df.dropna()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1338 entries, 2 to 2253
# Data columns (total 84 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   MUperGy       1338 non-null   float64
#  1   MUmin         1338 non-null   int64
#  2   MUmax         1338 non-null   float64
#  3   MUstd         1338 non-null   float64
#  4   MUiqr         1338 non-null   float64
#  5   AAV           1338 non-null   float64
#  6   AAVmin        1338 non-null   float64
#  7   AAVmax        1338 non-null   float64
#  8   AAVstd        1338 non-null   float64
#  9   AAViqr        1338 non-null   float64
#  10  LSV           1338 non-null   float64
#  11  LSVmin        1338 non-null   float64
#  12  LSVmax        1338 non-null   float64
#  13  LSVstd        1338 non-null   float64
#  14  LSViqr        1338 non-null   float64
#  15  MCS           1338 non-null   float64
#  16  MCSmin        1338 non-null   float64
#  17  MCSmax        1338 non-null   float64
#  18  MCSstd        1338 non-null   float64
#  19  MCSiqr        1338 non-null   float64
#  20  AFW           1338 non-null   float64
#  21  AFWmin        1338 non-null   float64
#  22  AFWmax        1338 non-null   float64
#  23  AFWstd        1338 non-null   float64
#  24  AFWiqr        1338 non-null   float64
#  25  ALT           1338 non-null   float64
#  26  CAS           1338 non-null   float64
#  27  CASmin        1338 non-null   int64
#  28  CASmax        1338 non-null   float64
#  29  CASstd        1338 non-null   float64
#  30  CASiqr        1338 non-null   float64
#  31  CLS           1338 non-null   float64
#  32  CLSmin        1338 non-null   float64
#  33  CLSmax        1338 non-null   float64
#  34  CLSstd        1338 non-null   float64
#  35  CLSiqr        1338 non-null   float64
#  36  MAD           1338 non-null   float64
#  37  MADmin        1338 non-null   int64
#  38  MADmax        1338 non-null   float64
#  39  MADstd        1338 non-null   float64
#  40  MADiqr        1338 non-null   float64
#  41  MFA           1338 non-null   float64
#  42  MFAmin        1338 non-null   int64
#  43  MFAmax        1338 non-null   float64
#  44  MFAstd        1338 non-null   float64
#  45  MFAiqr        1338 non-null   float64
#  46  SAS2          1338 non-null   float64
#  47  SAS2min       1338 non-null   int64
#  48  SAS2max       1338 non-null   float64
#  49  SAS2std       1338 non-null   float64
#  50  SAS2iqr       1338 non-null   float64
#  51  SAS5          1338 non-null   float64
#  52  SAS5min       1338 non-null   int64
#  53  SAS5max       1338 non-null   float64
#  54  SAS5std       1338 non-null   float64
#  55  SAS5iqr       1338 non-null   float64
#  56  SAS10         1338 non-null   float64
#  57  SAS10min      1338 non-null   int64
#  58  SAS10max      1338 non-null   float64
#  59  SAS10std      1338 non-null   float64
#  60  SAS10iqr      1338 non-null   float64
#  61  SAS20         1338 non-null   float64
#  62  SAS20min      1338 non-null   int64
#  63  SAS20max      1338 non-null   float64
#  64  SAS20std      1338 non-null   float64
#  65  SAS20iqr      1338 non-null   float64
#  66  EM            1338 non-null   float64
#  67  EMmin         1338 non-null   float64
#  68  EMmax         1338 non-null   float64
#  69  EMstd         1338 non-null   float64
#  70  EMiqr         1338 non-null   float64
#  71  MIt02         1338 non-null   float64
#  72  BI            1338 non-null   float64
#  73  BImin         1338 non-null   float64
#  74  BImax         1338 non-null   float64
#  75  BIstd         1338 non-null   float64
#  76  BIiqr         1338 non-null   float64
#  77  BM            1338 non-null   float64
#  78  BA            1338 non-null   float64
#  79  BAmin         1338 non-null   float64
#  80  BAmax         1338 non-null   float64
#  81  BAstd         1338 non-null   float64
#  82  BAiqr         1338 non-null   float64
#  83  Gamma22loc10  1338 non-null   float64
# dtypes: float64(76), int64(8)
# memory usage: 888.5 KB

# %% [markdown]
# # Sauvegarde de la base pelvis en csv

# %%
df.to_csv('/content/DataSet_RegionPelvienne.csv')

# %% [markdown]
# * Un csv a été créé dans les fichiers du projet
# * **Télécharger ce csv**
